# %%
import numpy as np
import string
from random import sample, choice
chars = string.letters + string.digits
length = 8

# %%
import pandas as pd

# %%
listpwd=np.array([''.join(choice(chars) for _ in range(length)) for _ in range(1103)])

# %%
len(np.unique(listpwd))
# Out:
# 1103

# %%
df = pd.read_csv('id.csv',names=['id'])

# %%
df['pwd']=listpwd

# %%
df
# Out:
#                      id       pwd
# 0     24950183708066836  XO1e0PO2
# 1     24950183708066837  tw4yCUnN
# 2     25002512700407821  RcdpSojS
# 3     24950183708066840  phxmEogy
# 4     24950183708066841  FnI3TwvV
# 5     24950183708066842  XO4xWxAh
# 6     24950183708066844  pIJaJFzF
# 7     24950183708066846  hC9KXRQe
# 8     24950183708066847  IG0VJ0PV
# 9     24950183708066848  xvDcSVGc
# 10    24950183708066849  aFe4kH3E
# 11    24950183708066851  jknZabUp
# 12    24950183708066852  qD0GqM3z
# 13    24950183708066853  n603S1N9
# 14    24950183708066854  7G46bYnl
# 15    24950183708066855  8CxeZbO7
# 16    24950183708066856  qSR53X3g
# 17    24950183708066857  Mq1L7v1D
# 18    24950183708066858  98fVlCUp
# 19    24950183708066859  RUSKMAHE
# 20    24950183708066860  OTGZLKjC
# 21    24950183708066861  Ip5nCkit
# 22    24950183708066862  nzIkM5J2
# 23    24950183708066863  0XqOuEKc
# 24    24950183708066864  85hs6IAQ
# 25    24950183708066865  CvuWNhRX
# ...

# %%
df.to_csv('out.csv',index=False)
